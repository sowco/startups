# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Цель-проекта" data-toc-modified-id="Цель-проекта-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Цель проекта</a></span><ul class="toc-item"><li><span><a href="#Исходные-данные:" data-toc-modified-id="Исходные-данные:-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Исходные данные:</a></span></li></ul></li><li><span><a href="#Исследование" data-toc-modified-id="Исследование-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование</a></span><ul class="toc-item"><li><span><a href="#Библиотеки" data-toc-modified-id="Библиотеки-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Библиотеки</a></span></li><li><span><a href="#Данные" data-toc-modified-id="Данные-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Данные</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Исправление-типов-данных" data-toc-modified-id="Исправление-типов-данных-2.3.1"><span class="toc-item-num">2.3.1&nbsp;&nbsp;</span>Исправление типов данных</a></span></li><li><span><a href="#Визуальный-анализ" data-toc-modified-id="Визуальный-анализ-2.3.2"><span class="toc-item-num">2.3.2&nbsp;&nbsp;</span>Визуальный анализ</a></span></li><li><span><a href="#Корректировка-данных" data-toc-modified-id="Корректировка-данных-2.3.3"><span class="toc-item-num">2.3.3&nbsp;&nbsp;</span>Корректировка данных</a></span><ul class="toc-item"><li><span><a href="#Добавим-lifetime-и-создаем-признаки-на-основе-дат" data-toc-modified-id="Добавим-lifetime-и-создаем-признаки-на-основе-дат-2.3.3.1"><span class="toc-item-num">2.3.3.1&nbsp;&nbsp;</span>Добавим lifetime и создаем признаки на основе дат</a></span></li><li><span><a href="#Удаляем-города,-частично-данные-пересекаются,-слишком-много-уникальных-значений" data-toc-modified-id="Удаляем-города,-частично-данные-пересекаются,-слишком-много-уникальных-значений-2.3.3.2"><span class="toc-item-num">2.3.3.2&nbsp;&nbsp;</span>Удаляем города, частично данные пересекаются, слишком много уникальных значений</a></span></li><li><span><a href="#Обрабатываем-пропуски" data-toc-modified-id="Обрабатываем-пропуски-2.3.3.3"><span class="toc-item-num">2.3.3.3&nbsp;&nbsp;</span>Обрабатываем пропуски</a></span></li></ul></li></ul></li><li><span><a href="#EDA" data-toc-modified-id="EDA-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>EDA</a></span><ul class="toc-item"><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Анализ данных</a></span></li><li><span><a href="#Матрица-корреляции" data-toc-modified-id="Матрица-корреляции-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Матрица корреляции</a></span></li><li><span><a href="#Проверяем-на-мультиколлинеарность" data-toc-modified-id="Проверяем-на-мультиколлинеарность-2.4.3"><span class="toc-item-num">2.4.3&nbsp;&nbsp;</span>Проверяем на мультиколлинеарность</a></span></li><li><span><a href="#Убираем-даты" data-toc-modified-id="Убираем-даты-2.4.4"><span class="toc-item-num">2.4.4&nbsp;&nbsp;</span>Убираем даты</a></span></li><li><span><a href="#Объединить-страны-где-меньше-N-наблюдений" data-toc-modified-id="Объединить-страны-где-меньше-N-наблюдений-2.4.5"><span class="toc-item-num">2.4.5&nbsp;&nbsp;</span>Объединить страны где меньше N наблюдений</a></span></li><li><span><a href="#Убираем-мелкие-шататы" data-toc-modified-id="Убираем-мелкие-шататы-2.4.6"><span class="toc-item-num">2.4.6&nbsp;&nbsp;</span>Убираем мелкие шататы</a></span></li><li><span><a href="#Объединяем-штаты-со-страной" data-toc-modified-id="Объединяем-штаты-со-страной-2.4.7"><span class="toc-item-num">2.4.7&nbsp;&nbsp;</span>Объединяем штаты со страной</a></span></li><li><span><a href="#Делаем-столбцы-из-типов" data-toc-modified-id="Делаем-столбцы-из-типов-2.4.8"><span class="toc-item-num">2.4.8&nbsp;&nbsp;</span>Делаем столбцы из типов</a></span></li><li><span><a href="#Обработаем-category_list" data-toc-modified-id="Обработаем-category_list-2.4.9"><span class="toc-item-num">2.4.9&nbsp;&nbsp;</span>Обработаем category_list</a></span></li><li><span><a href="#Обрабатываем-регионы" data-toc-modified-id="Обрабатываем-регионы-2.4.10"><span class="toc-item-num">2.4.10&nbsp;&nbsp;</span>Обрабатываем регионы</a></span></li><li><span><a href="#Убируем-получившиеся-мелкие-страны" data-toc-modified-id="Убируем-получившиеся-мелкие-страны-2.4.11"><span class="toc-item-num">2.4.11&nbsp;&nbsp;</span>Убируем получившиеся мелкие страны</a></span></li></ul></li><li><span><a href="#Строим-модель" data-toc-modified-id="Строим-модель-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Строим модель</a></span><ul class="toc-item"><li><span><a href="#Подготовка" data-toc-modified-id="Подготовка-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Подготовка</a></span></li><li><span><a href="#Обучение" data-toc-modified-id="Обучение-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Обучение</a></span></li><li><span><a href="#Анализ-важности-признаков" data-toc-modified-id="Анализ-важности-признаков-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Анализ важности признаков</a></span></li><li><span><a href="#Предсказание" data-toc-modified-id="Предсказание-2.5.4"><span class="toc-item-num">2.5.4&nbsp;&nbsp;</span>Предсказание</a></span></li></ul></li></ul></li><li><span><a href="#Отчет" data-toc-modified-id="Отчет-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Отчет</a></span><ul class="toc-item"><li><span><a href="#Введение" data-toc-modified-id="Введение-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Данные-и-методы-исследования" data-toc-modified-id="Данные-и-методы-исследования-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Данные и методы исследования</a></span></li><li><span><a href="#Описание-работы-и-результаты-исследования" data-toc-modified-id="Описание-работы-и-результаты-исследования-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Описание работы и результаты исследования</a></span></li><li><span><a href="#Заключение-и-выводы" data-toc-modified-id="Заключение-и-выводы-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Заключение и выводы</a></span></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Рекомендации</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Startups operations/close predictions
# Предсказание закрытия стартапа

# %% [markdown]
# **Выполнил:** Денис Фадеев @dv_fadeev

# %% [markdown]
# ## Цель проекта
# Разработать модель машинного обучения для предсказания продолжения деятельности стартапа.
# Провести полноценный разведочный анализ и сформировать рекомендации будущим создателям стартапов (какие факторы влияют на успешность стартапа).
#
# ###### Описание:
# Представлена информация о стартапах, которые функционировали в период с 1980 по 2018 годы. Нужно предсказать, какие из них закроются, а какие нет. Срок 2 недели.

# %% [markdown]
# ### Исходные данные:
#
# Датасет состоит из двух файлов (+пример с выгрузкой): тренировочный набор (около 53к записей) и тестовый набор (около 13к записей). Тренировочный набор содержит целевой признак status, указывающий на то, закрылся стартап или продолжает действовать. Временной период - '1970-01-01' по '2018-01-01'. Дата формирования выгрузки - '2018-01-01'
#
# kaggle_startups_train_01.csv - информация (53 000) стартапах, которые будут использоваться в качестве обучающих данных.
# kaggle_startups_test_01.csv - информация (13 000) стартапах, которые будут использоваться в качестве тестовых данных. Ваша задача - предсказать значение 'status' для каждого стартапа из этого датасета.
# kaggle_startups_sample_submit_01.csv - файл с примером предсказаний в правильном формате.
# name - идентификатор (название) стартапа в тестовом наборе.
# status - целевой признак. Для каждого стартапа предскажите категориальное значение соответствующее прогнозу ['operating', 'closed'].

# %% [markdown]
# ## Исследование

# %% [markdown]
# ### Библиотеки

# %%
# База и графики
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Дата и система
from IPython.display import Image
from datetime import datetime, timedelta

# Корреляция и анализ признаков
from phik import phik_from_array
from phik import phik_matrix
from phik.report import plot_correlation_matrix
import shap

# Модели, регрессии пока оставлю
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC


# Подготовка данных
from collections import Counter #Для словаря и списков
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import (
    OneHotEncoder, 
    OrdinalEncoder, 
    StandardScaler, 
    MinMaxScaler, 
    RobustScaler
    )

# Работа с пропусками
from sklearn.impute import SimpleImputer

# Подбор параметров
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# Функции для оценки
from sklearn.metrics import (
    f1_score,
    mean_absolute_error, 
    r2_score, 
    confusion_matrix, 
    recall_score, 
    precision_score,
    roc_curve,
    roc_auc_score
    )


# Настраиваю отображение
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.float_format', lambda x: '%.1f' % x)
# Out:
# The history saving thread hit an unexpected error (DatabaseError('database disk image is malformed')).History will not be written to the database.

# %% [markdown]
# ### Данные

# %%
# Дата выгрузки
dat_ext = datetime(2018, 1, 1)

# %%
startups_test = pd.read_csv('kaggle_startups_test_27042024.csv', sep=',') 
startups_submit = pd.read_csv('kaggle_startups_sample_submit_27042024.csv', sep=',')
startups_train = pd.read_csv('kaggle_startups_train_27042024.csv', sep=',')

def viewing_statistics(df_list):
    print('Посмотрим на данные:')
    for i in table:
        if len(i) >= 3:
            display(i.sample(3))
        else:
            display(i)
        display(i.info())
        display(i.columns)
        print('\n')
table = [startups_train, startups_submit, startups_test]   

viewing_statistics(table)
# Out:
# Посмотрим на данные:
#              name                                      category_list  \
# 22253    SynAgile                                      Biotechnology
# 26672  ZoVolt Ltd  Hardware|Internet|Manufacturing|Mobile|Sensors...
# 46451    Rutt Ett                                      Digital Media
#
#        funding_total_usd     status country_code state_code       region  \
# 22253           898618.0  operating          USA         CA  SF Bay Area
# 26672           147761.0  operating          GBR         F7     Hereford
# 46451           600000.0     closed          SWE         10  SWE - Other
#
#            city  funding_rounds  founded_at first_funding_at last_funding_at  \
# 22253  Piedmont               1  2010-08-04       2011-05-04      2011-05-04
# 26672  Hereford               1  2012-10-11       2013-10-01      2013-10-01
# 46451     Falun               1  2004-01-01       2015-09-28      2015-09-28
#
#         closed_at
# 22253         NaN
# 26672         NaN
# ...

# %% [markdown]
# **Выводы:**
# 1. Name - везде тип str.
# 2. Есть пропуски, нужно обработать.
# 3. Названия колонок соотвествуют стандарту.
# 4. Типы данных не везде верные, Даты нужно обработать (founded_at, first_funding_at, last_funding_at, closed_at), так же нужно проанализирвоать подробнее и возможно обработать funding_rounds.
# 5. Объем небольшой, сможем обрабатывать все в памяти.
#
# Надо понять как обрабатывать train и test, вместе или по отдельности.

# %% [markdown]
# ###  Предобработка данных
#
# #### Исправление типов данных

# %%
startups_train['founded_at'] = pd.to_datetime(startups_train['founded_at'])
startups_train['first_funding_at'] = pd.to_datetime(startups_train['first_funding_at'])
startups_train['last_funding_at'] = pd.to_datetime(startups_train['last_funding_at'])
startups_train['closed_at'] = pd.to_datetime(startups_train['closed_at'] )

startups_test['founded_at'] = pd.to_datetime(startups_test['founded_at'] )
startups_test['first_funding_at'] = pd.to_datetime(startups_test['first_funding_at'])
startups_test['last_funding_at'] = pd.to_datetime(startups_test['last_funding_at'])

# %% [markdown]
# #### Визуальный анализ

# %%
for j in [startups_train, startups_test]:
    for i in ['category_list', 'country_code', 'state_code', 'region', 'city', 'funding_rounds',]:
        unique_values = j[i].unique()
        print(f"\nУникальных значений в '{i}' - {len(unique_values)}, первые уникальные значения: {unique_values[:5]}")
# Out:
# Уникальных значений в 'category_list' - 22109, первые уникальные значения: ['Online Reservations|Restaurants' 'Manufacturing|Medical|Medical Devices'
#  'Biotechnology' 'Health Care' 'Manufacturing']
#
# Уникальных значений в 'country_code' - 135, первые уникальные значения: ['CHE' 'USA' nan 'GBR' 'RUS']
#
# Уникальных значений в 'state_code' - 301, первые уникальные значения: ['25' 'CA' nan 'VA' 'NJ']
#
# Уникальных значений в 'region' - 1037, первые уникальные значения: ['Zurich' 'SF Bay Area' nan 'VA - Other' 'Newark']
#
# Уникальных значений в 'city' - 4478, первые уникальные значения: ['Zürich' 'Redwood City' 'San Jose' nan 'Bristol']
#
# Уникальных значений в 'funding_rounds' - 19, первые уникальные значения: [2 4 3 1 5]
#
# Уникальных значений в 'category_list' - 6207, первые уникальные значения: ['Clean Technology' 'Hospitality' 'Finance'
#  'Software|Video|Video Streaming' 'Software']
#
# ...

# %%
def str_norm(df):
    str_columns = df.select_dtypes(include='object').columns.tolist()
    print('Столбцы с категориальными данными: ', str_columns,
         '\n \n Всего категориальных столбцов: ', len(str_columns))
    for column in str_columns:
        df[column] = df[column].str.strip()

str_norm(startups_train)        
str_norm(startups_submit)
str_norm(startups_test)
print('Обработали пробелы, \n обрабатываем дубликаты:') 

for df in [startups_train, startups_test]:
    print(f'Размеры таблицы : {len(df)} строк.')
    df.drop_duplicates(inplace=True)
    
print(f'\n Проверяем:')    
for df in [startups_train, startups_test]:
    print(f'Размеры таблицы : {len(df)} строк.')
    

table = [startups_train, startups_test]
print('Посмотрим на пропуски:')
for i in table:
    display(i.isnull().mean().sort_values())
    
print('Нужно обработать пропуски. \n')
    
viewing_statistics(table)
# Out:
# Столбцы с категориальными данными:  ['name', 'category_list', 'status', 'country_code', 'state_code', 'region', 'city']
#
#  Всего категориальных столбцов:  7
# Столбцы с категориальными данными:  ['name', 'status']
#
#  Всего категориальных столбцов:  2
# Столбцы с категориальными данными:  ['name', 'category_list', 'country_code', 'state_code', 'region', 'city']
#
#  Всего категориальных столбцов:  6
# Обработали пробелы,
#  обрабатываем дубликаты:
# Размеры таблицы : 52514 строк.
# Размеры таблицы : 13125 строк.
#
#  Проверяем:
# Размеры таблицы : 52514 строк.
# Размеры таблицы : 13125 строк.
# Посмотрим на пропуски:
# status              0.0
# funding_rounds      0.0
# founded_at          0.0
# first_funding_at    0.0
# last_funding_at     0.0
# name                0.0
# category_list       0.0
# country_code        0.1
# region              0.1
# city                0.1
# state_code          0.1
# funding_total_usd   0.2
# closed_at           0.9
# dtype: float64
# ...

# %% [markdown]
# #### Корректировка данных

# %%
startups_train['closed_at'] = startups_train['closed_at'].fillna(dat_ext)

# %% [markdown]
# ##### Добавим lifetime и создаем признаки на основе дат

# %%
startups_train['lifetime'] = (startups_train['closed_at'] - startups_train['founded_at']).dt.days
startups_train[:3]
# Out:
#                      name                          category_list  \
# 0               Lunchgate        Online Reservations|Restaurants
# 1                 EarLens  Manufacturing|Medical|Medical Devices
# 2  Reviva Pharmaceuticals                          Biotechnology
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
#
#            city  funding_rounds founded_at first_funding_at last_funding_at  \
# 0        Zürich               2 2009-12-31       2011-05-01      2014-12-01
# 1  Redwood City               4 2005-01-01       2010-05-04      2014-02-25
# 2      San Jose               3 2006-01-01       2012-08-20      2014-07-02
#
#    closed_at  lifetime
# 0 2018-01-01      2923
# 1 2018-01-01      4748
# 2 2018-01-01      4383

# %%
startups_train['time_first'] = startups_train['first_funding_at'] - startups_train['founded_at']
startups_train['time_first'] = startups_train['time_first'].dt.days.astype('int')
startups_train['time_last'] = startups_train['last_funding_at'] - startups_train['founded_at']
startups_train['time_last']  = startups_train['time_last'].dt.days.astype('int') 

startups_test['time_first'] = startups_test['first_funding_at'] - startups_test['founded_at']
startups_test['time_first'] = startups_test['time_first'].dt.days.astype('int')
startups_test['time_last'] = startups_test['last_funding_at'] - startups_test['founded_at']
startups_test['time_last']  = startups_test['time_last'].dt.days.astype('int')

# %% [markdown]
# ##### Удаляем города, частично данные пересекаются, слишком много уникальных значений

# %%
startups_train.drop('city', axis=1, inplace=True) 
startups_test.drop('city', axis=1, inplace=True)

# %% [markdown]
# ##### Обрабатываем пропуски

# %%
print(f"До {len(startups_train['country_code'])}")
def flna(df, col):
    if df[col].dtype in ['float64', 'int64']:
        # Если тип данных столбца числовой, заполняем медианой
        df[col] = df[col].fillna(df[col].median())
    elif df[col].dtype == 'object':
        # Если тип данных столбца строковый, заполняем самым частым значением
        most_frequent = df[col].mode()[0]
        df[col] = df[col].fillna(most_frequent)
    return df

for j in ('region', 'state_code', 'country_code'):
    startups_train =  startups_train.dropna(subset=[j], axis=0) # flna(startups_train, j) #
    startups_test = flna(startups_test, j)
        
# startups_train['funding_total_usd'] = startups_train['funding_total_usd'].fillna(startups_train['funding_total_usd'].mean())
startups_train = startups_train.dropna(subset=['funding_total_usd'], axis=0)
startups_test['funding_total_usd'] = startups_test['funding_total_usd'].fillna(startups_test['funding_total_usd'].mean())

print(f"После: {len(startups_train['country_code'])}")
# Out:
# До 52514
# После: 37591

# %%
   
startups_train['country_code'] = startups_train['country_code'].fillna('Not_ident')
startups_test['country_code'] = startups_test['country_code'].fillna('Not_ident')    
    
startups_train['state_code'] = startups_train['state_code'].fillna('Not_ident')
startups_test['state_code'] = startups_test['state_code'].fillna('Not_ident')    
    
startups_train['region'] = startups_train['region'].fillna('Not_ident')
startups_test['region'] = startups_test['region'].fillna('Not_ident')
    
    
startups_train['funding_total_usd'] = startups_train['funding_total_usd'].fillna(startups_train['funding_total_usd'].mean())
startups_test['funding_total_usd'] = startups_test['funding_total_usd'].fillna(startups_test['funding_total_usd'].mean())

# %%
print('Посмотрим на пропуски:')
for i in table:
    display(i.isnull().mean().sort_values())
    
print('Пропуски обработаны. \n')
# Out:
# Посмотрим на пропуски:
# status              0.0
# funding_rounds      0.0
# founded_at          0.0
# first_funding_at    0.0
# last_funding_at     0.0
# closed_at           0.0
# lifetime            0.0
# time_first          0.0
# time_last           0.0
# name                0.0
# category_list       0.0
# country_code        0.1
# region              0.1
# state_code          0.1
# funding_total_usd   0.2
# dtype: float64
# name                0.0
# funding_total_usd   0.0
# country_code        0.0
# state_code          0.0
# region              0.0
# funding_rounds      0.0
# founded_at          0.0
# first_funding_at    0.0
# last_funding_at     0.0
# lifetime            0.0
# time_first          0.0
# time_last           0.0
# category_list       0.0
# dtype: float64
# Пропуски обработаны.

# %% [markdown]
# **Выводы:**
# 1. Пропуски исправили.
# 2. Типы данных скорректировали.
# 3. Неявные дубликаты не проверял. На таком массиве уникальных значений не целесообразно.
# 4. Удалил дубли.
# 5. Удалил Города.
# 6. Разобрал Категории.

# %% [markdown]
# ### EDA
# #### Анализ данных

# %%
def e_d_a(variable, name, table):
    print(f'Смотрим статистику: {name}')
    # Статистика
    display(table[variable].describe())

    # Гистограмма
    plt.figure(figsize=(15, 6))
    table[variable].hist(bins=30, range=(max(0, table[variable].min()), table[variable].max()))
    plt.title(f'Распределение {name}')
    plt.xlabel(f'{name}')
    plt.ylabel('Частота')
    plt.show()
    
    # Диаграмма с усами
    plt.figure(figsize=(15, 4))
    table.boxplot(column=variable, vert=False, color='green', widths=0.6)
    plt.title(f'Диаграмма межквартильного размаха для {name}')
    plt.xlabel(f'{name}')
    plt.yticks([]) 
    plt.grid(True, linestyle='--', alpha=0.2, linewidth=1.5)
    plt.show()


    # Описание границ
    print('\n', f'{name} находится в диапазоне от {table[variable].min():.2f}',
          f'до {table[variable].max():.2f}, посмотрим как распределяются данные, видим на графике выше:'
         )

    # Вывод 75% и 98% квантилей
    print(f'75% объектов находятся в диапазоне до {table[variable].quantile(0.75):.1f}',
          f'\n \n Всего значений отличных от 0: {len(table[table[variable]>0]):.1f}.',
          f'\n 1Q = {table[variable].quantile(0.25):.1f},',
          f'\n 3Q = {table[variable].quantile(0.75):.1f},',
          f'\n Межквартильный размах = {(table[variable].quantile(0.75) - table[variable].quantile(0.25)):.1f},',
         )
    
def e_d_a_categorical(variable, name, table):
    counts = table[variable].value_counts().sort_values(ascending=False)
    print(f'Смотрим статистику: {name}')
    display(table[variable].describe())
    print('Лидеров и аутсайдеров: ')
    display(counts)
    if len(counts)>20:
        print('Посмотрим на графике ТОП-10: ')
        plt.bar(counts.head(10).index, counts.head(10).values)
        plt.xlabel(name)
        plt.ylabel('Количество')
        plt.title(f'Распределение признака {name}')
        plt.xticks(rotation=45, ha='right')
        plt.ylim(counts.min()*0.9, counts.max()*1.05)
        plt.show()
    else: 
        print('Посмотрим на графике: ')
        plt.bar(counts.head(10).index, counts.head(10).values)
        plt.xlabel(name)
        plt.ylabel('Количество')
        plt.title(f'Распределение признака {name}')
        plt.xticks(rotation=45, ha='right')
        plt.ylim(counts.min()*0.9, counts.max()*1.05)
        plt.show()
        
        
def e_d_a_spl(variable, name, table):
    print(f'Смотрим статистику: {name}')
    # Статистика
    display(table[variable].describe())

    # Гистограмма
    plt.figure(figsize=(15, 6))
    for j, group in table.groupby('status'):
        group[variable].hist(
            bins=30, range=(max(0, group[variable].min()), group[variable].max()), 
            alpha=0.5, 
            label=j)
    plt.title(f'Распределение {name}')
    plt.xlabel(f'{name}')
    plt.ylabel('Частота')
    plt.legend()
    plt.show()

    # Диаграмма с усами
    plt.figure(figsize=(15, 4))
    table.boxplot(
        column=variable, by='status', vert=False, color='green', widths=0.6)
    plt.title(f'Диаграмма межквартильного размаха для {name}')
    plt.xlabel(f'{name}')
    plt.yticks([])  # Убираем метки по оси Y, так как она не используется
    plt.grid(True, linestyle='--', alpha=0.2, linewidth=1.5)
    plt.show()


    # Описание границ
    print('\n', f'{name} находится в диапазоне от {table[variable].min():.2f}',
          f'до {table[variable].max():.2f}, посмотрим как распределяются данные, видим на графике выше:'
         )

    # Вывод 75% и 98% квантилей
    print(f'75% объектов находятся в диапазоне до {table[variable].quantile(0.75):.1f}',
          f'\n \n Всего значений отличных от 0: {len(table[table[variable]>0]):.1f}.',
          f'\n 1Q = {table[variable].quantile(0.25):.1f},',
          f'\n 3Q = {table[variable].quantile(0.75):.1f},',
          f'\n Межквартильный размах = {(table[variable].quantile(0.75) - table[variable].quantile(0.25)):.1f},',
         )
    
def e_d_a_categorical_spl(variable, name, table):
    counts = table[variable].value_counts().sort_values(ascending=False)
    print(f'Смотрим статистику: {name}')
    display(table[variable].describe())
    print('Лидеров и аутсайдеров: ')
    display(counts)
    # Создание списка уникальных значений в колонке "Покуп. акт."
    unique_values = table['status'].unique()

    # Создание цветов
    colors = ['green', 'orange'] 

    if len(counts)>20:
        print('Посмотрим на графике ТОП-10: ')

        # Построение графиков для каждого уникального значения
        for i, value in enumerate(unique_values):
            counts = table[table['status'] == value][variable].value_counts()
            plt.bar(counts.head(10).index, counts.head(10).values, alpha=0.5, label=value, color=colors[i % len(colors)])
        plt.xlabel(name)
        plt.ylabel('Количество')
        plt.title('Сравнение значений в колонке Статус')
        plt.xticks(rotation=45, ha='right')
        plt.legend()
        plt.show()
    else: 
        print('Посмотрим на графике: ')
        # Построение графиков для каждого уникального значения
        for i, value in enumerate(unique_values):
            counts = table[table['status'] == value][variable].value_counts()
            plt.bar(counts.head(10).index, counts.head(10).values, alpha=0.5, label=value, color=colors[i % len(colors)])
        plt.xlabel(name)
        plt.ylabel('Количество')
        plt.title('Сравнение значений в колонке Статус')
        plt.xticks(rotation=45, ha='right')
        plt.legend()
        plt.show()

# %%
def type_col(df):
    numeric_columns = df.select_dtypes(include='number').columns
    text_columns = df.select_dtypes(include='object').columns
    boolean_columns = df.select_dtypes(include='bool').columns
    print(f'Числовые признаки: {numeric_columns.tolist()}\n', 
          f'Логические признаки: {boolean_columns.tolist()} \n',
          f'Строковые признаки: {text_columns.tolist()} \n',)
    try:
        display(df[numeric_columns.tolist()].describe())
    except:
        print('\n')
    try:
        display(df[boolean_columns.tolist()].describe())
    except:
        print('\n')
    try:
        display(df[text_columns.tolist()].describe())
    except:
        print('\n')
    
    
    
for i in table:
    type_col(i)
# Out:
# Числовые признаки: ['funding_total_usd', 'funding_rounds', 'lifetime', 'time_first', 'time_last']
#  Логические признаки: []
#  Строковые признаки: ['name', 'category_list', 'status', 'country_code', 'state_code', 'region']
#        funding_total_usd  funding_rounds  lifetime  time_first  time_last
# count            42445.0         52514.0   52514.0     52514.0    52514.0
# mean          18248256.0             1.7    3141.0       984.8     1331.3
# std          187121675.7             1.4    2147.9      1650.2     1773.9
# min                  1.0             1.0      17.0     -9465.0    -9465.0
# 25%             336000.0             1.0    1740.0       214.2      336.0
# 50%            2000000.0             1.0    2557.0       479.0      680.0
# 75%           10000000.0             2.0    4018.0       976.0     1642.0
# max        30079503000.0            19.0   17378.0     16313.0    16313.0
#              name category_list     status country_code state_code  \
# ...

# %%
e_d_a_categorical_spl('country_code', 'Код страны', startups_train)
e_d_a_categorical('country_code', 'Код страны', startups_test)
# Out:
# Смотрим статистику: Код страны
# count     37591
# unique      110
# top         USA
# freq      24794
# Name: country_code, dtype: object
# Лидеров и аутсайдеров:
# USA    24794
# GBR     2352
# CAN     1258
# IND      933
# CHN      891
#        ...
# RWA        1
# TGO        1
# NPL        1
# GTM        1
# SYC        1
# Name: country_code, Length: 110, dtype: int64
# Посмотрим на графике ТОП-10:
# Смотрим статистику: Код страны
# count     13125
# unique       96
# top         USA
# freq       8810
# Name: country_code, dtype: object
# Лидеров и аутсайдеров:
# USA    8810
# GBR     725
# CAN     369
# IND     307
# CHN     301
#        ...
# MUS       1
# BMU       1
# HRV       1
# PSE       1
# ZMB       1
# Name: country_code, Length: 96, dtype: int64
# Посмотрим на графике ТОП-10:

# %%
e_d_a_categorical_spl('state_code', 'Код штата', startups_train)
e_d_a_categorical('state_code', 'Код штата', startups_test)
# Out:
# Смотрим статистику: Код штата
# count     37591
# unique      286
# top          CA
# freq       8746
# Name: state_code, dtype: object
# Лидеров и аутсайдеров:
# CA    8746
# NY    2629
# MA    1841
# TX    1281
# H9    1250
#       ...
# D7       1
# Y2       1
# 41       1
# T6       1
# L6       1
# Name: state_code, Length: 286, dtype: int64
# Посмотрим на графике ТОП-10:
# Смотрим статистику: Код штата
# count     13125
# unique      235
# top          CA
# freq       4247
# Name: state_code, dtype: object
# Лидеров и аутсайдеров:
# CA    4247
# NY     789
# MA     487
# TX     410
# H9     382
#       ...
# VI       1
# U3       1
# 39       1
# P2       1
# W3       1
# Name: state_code, Length: 235, dtype: int64
# Посмотрим на графике ТОП-10:

# %%
e_d_a_spl('funding_total_usd', 'Бюджет', startups_train)
e_d_a('funding_total_usd', 'Бюджет', startups_test)
# Out:
# Смотрим статистику: Бюджет
# count         37591.0
# mean       18720144.1
# std       186345857.3
# min               1.0
# 25%          400844.0
# 50%         2200000.0
# 75%        10725882.8
# max     30079503000.0
# Name: funding_total_usd, dtype: float64
#  Бюджет находится в диапазоне от 1.00 до 30079503000.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 10725882.8
#
#  Всего значений отличных от 0: 37591.0.
#  1Q = 400844.0,
#  3Q = 10725882.8,
#  Межквартильный размах = 10325038.8,
# Смотрим статистику: Бюджет
# count        13125.0
# mean      16549102.7
# std       82625418.8
# min              1.0
# 25%         501000.0
# 50%        4297285.0
# 75%       16549102.7
# max     4715000000.0
# Name: funding_total_usd, dtype: float64
#  Бюджет находится в диапазоне от 1.00 до 4715000000.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 16549102.7
#
# ...

# %% [markdown]
# Убираем выбросы в бюджете

# %%
print('До ', len(startups_train))
startups_train = startups_train[(startups_train['funding_total_usd']>np.percentile(startups_train['funding_total_usd'], 1)) & 
                                (startups_train['funding_total_usd']<np.percentile(startups_train['funding_total_usd'], 97))]
print('После ', len(startups_train))
# Out:
# До  37591
# После  35972

# %%
e_d_a_spl('funding_total_usd', 'Бюджет', startups_train)
e_d_a('funding_total_usd', 'Бюджет', startups_test)
# Out:
# Смотрим статистику: Бюджет
# count       35972.0
# mean      9400884.6
# std      17056684.0
# min         10100.0
# 25%        415781.2
# 50%       2035702.0
# 75%      10000000.0
# max     101750000.0
# Name: funding_total_usd, dtype: float64
#  Бюджет находится в диапазоне от 10100.00 до 101750000.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 10000000.0
#
#  Всего значений отличных от 0: 35972.0.
#  1Q = 415781.2,
#  3Q = 10000000.0,
#  Межквартильный размах = 9584218.8,
# Смотрим статистику: Бюджет
# count        13125.0
# mean      16549102.7
# std       82625418.8
# min              1.0
# 25%         501000.0
# 50%        4297285.0
# 75%       16549102.7
# max     4715000000.0
# Name: funding_total_usd, dtype: float64
#  Бюджет находится в диапазоне от 1.00 до 4715000000.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 16549102.7
#
# ...

# %%
e_d_a_spl('funding_rounds', 'Раунды', startups_train)
e_d_a('funding_rounds', 'Раунды', startups_test)
# Out:
# Смотрим статистику: Раунды
# count   35972.0
# mean        1.9
# std         1.4
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         2.0
# max        18.0
# Name: funding_rounds, dtype: float64
#  Раунды находится в диапазоне от 1.00 до 18.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 2.0
#
#  Всего значений отличных от 0: 35972.0.
#  1Q = 1.0,
#  3Q = 2.0,
#  Межквартильный размах = 1.0,
# Смотрим статистику: Раунды
# count   13125.0
# mean        1.7
# std         1.3
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         2.0
# max        15.0
# Name: funding_rounds, dtype: float64
#  Раунды находится в диапазоне от 1.00 до 15.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 2.0
#
#  Всего значений отличных от 0: 13125.0.
#  1Q = 1.0,
#  3Q = 2.0,
#  Межквартильный размах = 1.0,

# %%
e_d_a_categorical_spl('funding_rounds', 'Раунды', startups_train)
e_d_a_categorical('funding_rounds', 'Раунды', startups_test)
# Out:
# Смотрим статистику: Раунды
# count   35972.0
# mean        1.9
# std         1.4
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         2.0
# max        18.0
# Name: funding_rounds, dtype: float64
# Лидеров и аутсайдеров:
# 1     19904
# 2      8166
# 3      3942
# 4      1963
# 5       983
# 6       487
# 7       250
# 8       110
# 9        72
# 10       44
# 11       19
# 12       14
# 13        6
# 15        4
# 16        3
# 18        2
# 14        2
# 17        1
# Name: funding_rounds, dtype: int64
# Посмотрим на графике:
# Смотрим статистику: Раунды
# count   13125.0
# mean        1.7
# std         1.3
# min         1.0
# 25%         1.0
# 50%         1.0
# 75%         2.0
# max        15.0
# Name: funding_rounds, dtype: float64
# Лидеров и аутсайдеров:
# 1     8449
# 2     2426
# 3     1111
# 4      533
# 5      288
# 6      152
# 7       75
# 8       39
# 9       17
# 10      16
# 12       6
# 13       6
# 11       5
# 15       1
# 14       1
# ...

# %%
e_d_a_spl('lifetime', 'Время жизни', startups_train)
e_d_a('lifetime', 'Время жизни', startups_test)
# Out:
# Смотрим статистику: Время жизни
# count   35972.0
# mean     3273.8
# std      2129.3
# min        62.0
# 25%      1826.0
# 50%      2570.0
# 75%      4018.0
# max     17167.0
# Name: lifetime, dtype: float64
#  Время жизни находится в диапазоне от 62.00 до 17167.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 4018.0
#
#  Всего значений отличных от 0: 35972.0.
#  1Q = 1826.0,
#  3Q = 4018.0,
#  Межквартильный размах = 2192.0,
# Смотрим статистику: Время жизни
# count   13125.0
# mean     3098.2
# std      2128.5
# min        79.0
# 25%      1729.0
# 50%      2526.0
# 75%      3871.0
# max     17167.0
# Name: lifetime, dtype: float64
#  Время жизни находится в диапазоне от 79.00 до 17167.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 3871.0
#
#  Всего значений отличных от 0: 13125.0.
#  1Q = 1729.0,
#  3Q = 3871.0,
#  Межквартильный размах = 2142.0,

# %%
e_d_a_spl('time_first', 'Время первого', startups_train)
e_d_a('time_first', 'Время первого', startups_test)
# Out:
# Смотрим статистику: Время первого
# count   35972.0
# mean     1031.6
# std      1652.8
# min     -4618.0
# 25%       233.0
# 50%       511.0
# 75%      1101.0
# max     15977.0
# Name: time_first, dtype: float64
#  Время первого находится в диапазоне от -4618.00 до 15977.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 1101.0
#
#  Всего значений отличных от 0: 32617.0.
#  1Q = 233.0,
#  3Q = 1101.0,
#  Межквартильный размах = 868.0,
# Смотрим статистику: Время первого
# count   13125.0
# mean      955.0
# std      1617.8
# min     -3661.0
# 25%       211.0
# 50%       470.0
# 75%       943.0
# max     15889.0
# Name: time_first, dtype: float64
#  Время первого находится в диапазоне от -3661.00 до 15889.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 943.0
#
#  Всего значений отличных от 0: 11733.0.
#  1Q = 211.0,
#  3Q = 943.0,
#  Межквартильный размах = 732.0,

# %%
e_d_a_spl('time_last', 'Время последнего', startups_train)
e_d_a('time_last', 'Время последнего', startups_test)
# Out:
# Смотрим статистику: Время последнего
# count   35972.0
# mean     1451.1
# std      1776.2
# min     -4618.0
# 25%       408.0
# 50%       831.0
# 75%      1842.0
# max     16005.0
# Name: time_last, dtype: float64
#  Время последнего находится в диапазоне от -4618.00 до 16005.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 1842.0
#
#  Всего значений отличных от 0: 34357.0.
#  1Q = 408.0,
#  3Q = 1842.0,
#  Межквартильный размах = 1434.0,
# Смотрим статистику: Время последнего
# count   13125.0
# mean     1283.3
# std      1734.8
# min     -3661.0
# 25%       328.0
# 50%       660.0
# 75%      1579.0
# max     15889.0
# Name: time_last, dtype: float64
#  Время последнего находится в диапазоне от -3661.00 до 15889.00, посмотрим как распределяются данные, видим на графике выше:
# 75% объектов находятся в диапазоне до 1579.0
#
#  Всего значений отличных от 0: 12289.0.
#  1Q = 328.0,
#  3Q = 1579.0,
# ...

# %% [markdown]
# ####  Матрица корреляции

# %%
correlation_matrix = startups_train[startups_train.select_dtypes(include='number').columns.tolist()].corr(method='spearman')
plt.figure(figsize=(9, 7))
  
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.1f')
plt.title('Матрица корреляции')
plt.show()

# %% [markdown]
# #### Проверяем на мультиколлинеарность

# %%
phik_corr_matrix = phik_matrix(startups_train[[
        'funding_total_usd', 'status', 'country_code',
        'state_code', 'region', 'funding_rounds',
        'lifetime',
        'time_first', 'time_last']])
# Out:
# interval columns not set, guessing: ['funding_total_usd', 'funding_rounds', 'lifetime', 'time_first', 'time_last']

# %%
plot_correlation_matrix(phik_corr_matrix.values, x_labels=phik_corr_matrix.columns, y_labels=phik_corr_matrix.index, 
                        vmin=0, vmax=1, color_map='Blues', title=r'Матрица корреляции $\phi_K$', fontsize_factor=1.1,
                        figsize=(7,5.5))
plt.tight_layout()

# %%
# Создание матрицы рассеяния
scatter_matrix = pd.plotting.scatter_matrix(startups_train[[
    'funding_total_usd', 'status', 'country_code',
    'state_code', 'region', 'funding_rounds',
    'lifetime', 'time_first', 'time_last']])

plt.suptitle('Матрица рассеяния', y=1.02)
for ax in scatter_matrix.ravel():
    ax.yaxis.label.set_rotation(45)
    ax.yaxis.label.set_ha('right')
    ax.xaxis.label.set_rotation(45)
    ax.xaxis.label.set_ha('right')

plt.show()

# %% [markdown]
# Как видим время финансирования и коды регионов и штатов имеют мультиколлинеарность, тем неменее при удалении одного из факторов модель теряет в точности, это видно на графиках рассеяния: они дополняют друг друга.
#
# В точности теряется не значительно, если будет вопрос ускорения модели, можно будет пожертвовать этими факторами.

# %%
startups_train['status'].unique()
# Out:
# array(['operating', 'closed'], dtype=object)

# %%
# Группировка 
grouped_data_close = startups_train[startups_train['status'] == 'closed'].groupby(startups_train['founded_at'].dt.year).size()
grouped_data_open = startups_train[startups_train['status'] == 'operating'].groupby(startups_train['founded_at'].dt.year).size()

# Создание линейного графика
plt.plot(grouped_data_close.index, grouped_data_close.values, label='closed', color='orange', marker='+')
plt.plot(grouped_data_open.index, grouped_data_open.values, label= 'operating', color='blue', marker='o')

# Легенда
plt.title('Количество стартапов по году основания и статусу')
plt.xlabel('Год основания')
plt.ylabel('Количество стартапов')
plt.legend(title='Статус', loc='upper left')

# Отображение графика
plt.savefig('динамика стартапов.png')
plt.show()

# %% [markdown]
# #### Убираем даты

# %%
startups_train.drop(['first_funding_at', 'last_funding_at', 'founded_at', 'closed_at'], axis=1, inplace=True)
startups_test.drop(['first_funding_at', 'last_funding_at', 'founded_at'], axis=1, inplace=True)

# %% [markdown]
# #### Объединить страны где меньше N наблюдений

# %%
def filter_category(df_col, tresh):
    list_category = [item for item in df_col] 
    # Считаем вхождения
    counter = Counter(list_category)
    # Сортируем по убыванию
    sorted_counter = dict(counter.most_common())
    filtered_data = {key: value for key, value in sorted_counter.items() if value > tresh}
    # Создадим список ключей из отфильтрованного словаря
    keys_list = list(filtered_data.keys())
    return keys_list

def replace_N_col(code, valid_keys):
    if code in valid_keys:
        return code
    else:
        return 'Other'

def comb_country_state(country_code, state_code):
    if country_code == 'USA':
        return f'{country_code}_{state_code}'
    return country_code

# %%
print(f"До {len(startups_train['country_code'].unique())}")
key_country = filter_category(startups_train['country_code'], 10)
startups_train['country_code'] = startups_train['country_code'].apply(replace_N_col, valid_keys=key_country)
startups_test['country_code'] = startups_test['country_code'].apply(replace_N_col, valid_keys=key_country)
print(f"После {len(startups_train['country_code'].unique())}")
# Out:
# До 104
# После 59

# %% [markdown]
# ####  Убираем мелкие шататы

# %%
print(f"До {len(startups_train['state_code'].unique())}")
key_state = filter_category(startups_train['state_code'], 25) #Было 40
startups_train['state_code'] = startups_train['state_code'].apply(replace_N_col, valid_keys=key_state)
startups_test['state_code'] = startups_test['state_code'].apply(replace_N_col, valid_keys=key_state)
print(f"После {len(startups_train['state_code'].unique())}")
# Out:
# До 285
# После 104

# %% [markdown]
# #### Объединяем штаты со страной

# %%
startups_train['country_code'] = startups_train.apply(
    lambda row: comb_country_state(row['country_code'], row['state_code']), axis=1
    )

# %% [markdown]
# #### Делаем столбцы из типов

# %% [markdown]
# #### Обработаем category_list

# %%
# Функция для разделения строки по '|'
def split_values(row):
    return row.split('|')

# Применяем 
startups_train['category_list'] = startups_train['category_list'].fillna('Other')
startups_train['category_list'] = startups_train['category_list'].apply(split_values)

# %%
list_category = [item for sublist in startups_train['category_list'] for item in sublist]
# Считаем вхождения
counter = Counter(list_category)
# Сортируем по убыванию
sorted_counter = dict(counter.most_common())

# Извлекаем значения
values = np.array(list(sorted_counter.values()))

# Ищем базу
average_count = np.median(values)

# Ищем точку отсечения
percentile_0 = np.percentile(values,10)

# print(f"Отсортированный Counter: {sorted_counter}")
print(f"Медиана количество: {average_count}")
print(f"Нижние 20%: {percentile_0}")

# Убираем дубликаты из общего списка
list_category  = list(set(list_category ))
print('Всего: ', len(list_category))

# Выводим количество вхождений каждого элемента
# for item, count in sorted_counter.items():
#     print(f'{item}: {count}')
    
# Оставим только популярные категории
filtered_keys = [key for key, value in sorted_counter.items() if value > 10]
# Создание нового словаря с отфильтрованными ключами
filtered_dict = {key: sorted_counter[key] for key in filtered_keys}

filtered_dict = {key: sorted_counter[key] for key in filtered_keys}

# Сортировка
filtered_dict = dict(sorted(filtered_dict.items(), key=lambda item: item[1], reverse=True))

print('Всего: ', len(filtered_dict))
# for item, count in filtered_dict.items():
#     print(f'{item}: {count}')

# Делаем список
list_category = list(set(filtered_keys))
len(list_category)
# Out:
# Медиана количество: 26.0
# Нижние 20%: 3.0
# Всего:  843
# Всего:  599
# 599

# %%
# # Для обработки списков и уменьшения его
def replace_N_col_type(state_codes, valid_keys):
    if isinstance(state_codes, list):
        return [state_code if state_code in valid_keys else 'Other' for state_code in state_codes]
    else:
        return 'Other' if state_codes not in valid_keys else state_codes
    
# # Создаем новые колонки заполняем его
def create_columns_for_categories(df, categories):
    for category in categories:
        df[category] = df['category_list'].apply(lambda x: 1 if category in x else 0)
    return df

startups_train['category_list'] = startups_train['category_list'].apply(replace_N_col_type, valid_keys=list_category)
startups_test['category_list'] = startups_test['category_list'].apply(replace_N_col_type, valid_keys=list_category)

# %%
startups_train = create_columns_for_categories(startups_train, list_category)
startups_test = create_columns_for_categories(startups_test, list_category)

startups_train.drop(['category_list', 'state_code'], axis=1, inplace=True)
startups_test.drop(['category_list', 'state_code'], axis=1, inplace=True)

# %% [markdown]
# #### Обрабатываем регионы

# %%
# startups_train.drop('region', axis=1, inplace=True) 
# startups_test.drop('region', axis=1, inplace=True) 
print(f"До {len(startups_train['region'].unique())}")
key_state = filter_category(startups_train['region'], 30)
startups_train['region'] = startups_train['region'].apply(replace_N_col, valid_keys=key_state)
startups_test['region'] = startups_test['region'].apply(replace_N_col, valid_keys=key_state)
print(f"После {len(startups_train['region'].unique())}")
# Out:
# До 943
# После 142

# %% [markdown]
# #### Убируем получившиеся мелкие страны

# %%
print(f"До {len(startups_train['country_code'].unique())}")
key_state = filter_category(startups_train['country_code'], 25)
startups_train['country_code'] = startups_train['country_code'].apply(replace_N_col, valid_keys=key_state)
startups_test['country_code'] = startups_test['country_code'].apply(replace_N_col, valid_keys=key_state)
print(f"После {len(startups_train['country_code'].unique())}")
# Out:
# До 104
# После 92

# %% [markdown]
# ### Строим модель
#
# #### Подготовка

# %%
print('До ', len(startups_train))
startups_train = startups_train.dropna(subset=['status'], axis=0) 
startups_train['status'] = startups_train['status'].map({'operating': 0, 'closed': 1})
startups_train = startups_train[(startups_train['time_first']>0)&
#                                 (startups_train['time_first']<9000)&
                                (startups_train['time_last']>0)]

print('После ', len(startups_train))
# Out:
# До  35972
# После  32617

# %% [markdown]
# #### Обучение

# %%
RANDOM_STATE = 68
TEST_SIZE = 0.2
threshold = 0.45


startups_train = startups_train.fillna(0)
startups_train['funding_total_usd'] = startups_train['funding_total_usd']
startups_train['lifetime'] = startups_train['lifetime'].astype(float)
startups_train['time_first'] = startups_train['time_first'].astype(float)
startups_train['time_last'] = startups_train['time_last'].astype(float)
startups_train['funding_rounds'] = startups_train['funding_rounds'].astype(float)
# startups_train = startups_train[(startups_train['time_first']>0)&(startups_train['time_last']>0)]

startups_train['country_code'] = startups_train['country_code'].astype(str)
    
    
X_train, X_test, y_train, y_test = train_test_split(
    startups_train.drop([
        'status', 
        'name', 
    ], axis=1),
    startups_train['status'],
    test_size = TEST_SIZE, 
    random_state = RANDOM_STATE,
    stratify = startups_train['status']
    )

# создаём списки с названиями признаков
ohe_columns = X_train.select_dtypes(include=['category', 'object']).columns
num_columns = X_train.select_dtypes(include='number').columns

# создаём пайплайн для подготовки признаков из списка ohe_columns: заполнение пропусков и OHE-кодирование
# SimpleImputer + OHE
ohe_pipe = Pipeline(
    [('simpleImputer_ohe', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore'))
    ]
    )
# создаём пайплайн для подготовки признаков из списка ord_columns: заполнение пропусков и Ordinal-кодирование
# SimpleImputer + OE
ord_pipe = Pipeline(
    [('simpleImputer_before_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent')),
     ('simpleImputer_after_ord', SimpleImputer(missing_values=np.nan, strategy='most_frequent'))
    ]
)

# создаём общий пайплайн для подготовки данных
data_preprocessor = ColumnTransformer(
    [
    ('ohe', ohe_pipe, ohe_columns),
     ('num', MinMaxScaler(), num_columns)
    ], 
    remainder='passthrough'
)

# создаём итоговый пайплайн: подготовка данных и модель
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('models', DecisionTreeClassifier(random_state=RANDOM_STATE, class_weight='balanced'))
])

param_grid = [
    # словарь для модели CatBoostClassifier
    {
        'models': [CatBoostClassifier(random_state=RANDOM_STATE, silent=True)],
        'models__iterations': range(1, 30, 5),
        'models__depth': range(1, 20, 5),
        'models__l2_leaf_reg': range(1, 10, 2),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    },
    
#     словарь для модели XGBClassifier()
    {
        'models': [XGBClassifier(random_state=RANDOM_STATE, use_label_encoder=False, eval_metric='logloss')],
        'models__n_estimators': range(1, 50, 5),
        'models__learning_rate': [.01, .001, 0.1, 0.6, 0.7, 0.8, 0.9, 1.1],
        'models__max_depth': range(1, 25, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler(), 'passthrough']
    }
]
randomized_search = RandomizedSearchCV(
    pipe_final, 
    param_grid, 
    cv=5,
    scoring= 'f1',  # Используем f1_score
    random_state=RANDOM_STATE,
    n_jobs=-1
)

randomized_search.fit(X_train, y_train)


print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print(f'F1 метрика лучшей модели на тренировочной выборке:: {randomized_search.best_score_}')

best_model = randomized_search.best_estimator_

# Используем predict_proba если доступно, иначе decision_function
if hasattr(best_model, "predict_proba"):
    y_test_pred_proba = best_model.predict_proba(X_test)[:, 1]
elif hasattr(best_model, "decision_function"):
    y_test_pred_proba = best_model.decision_function(X_test)
else:
    raise AttributeError("Модель не поддерживает predict_proba или decision_function")
    
y_test_pred = (y_test_pred_proba >= threshold).astype(int)
roc_auc = roc_auc_score(y_test, y_test_pred_proba)
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred)}')
print(f'Метрика ROC-AUC на тестовой выборке: {roc_auc_score(y_test, y_test_pred_proba)}')


y_test_pred = (y_test_pred_proba >= threshold).astype(int)
print(f'Метрика F1 на тестовой выборке: {f1_score(y_test, y_test_pred, average="weighted")}')
print(f'Метрика F1 на тестовой выборке: {f1_score(y_test, y_test_pred)}')
# Out:
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   Index(['country_code', 'region'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['funding_total_usd', 'funding_rounds...
# ...

# %% [markdown]
# #### Анализ важности признаков

# %%
print('Анализируем важность признаков в лучшей модели.')

X_train_2 = pipe_final.named_steps['preprocessor'].fit_transform(X_train)
explainer = shap.Explainer(randomized_search.best_estimator_.named_steps['models'], X_train_2)
X_test_2 = pipe_final.named_steps['preprocessor'].transform(X_test)
feature_names = pipe_final.named_steps['preprocessor'].get_feature_names_out()
X_test_2 = pd.DataFrame(X_test_2, columns=feature_names)

shap_values = explainer(X_test_2)


shap.plots.beeswarm(shap_values, max_display=22)

# Сохранение графика
plt.figure(figsize=(10, 6))
shap.summary_plot(shap_values, X_test_2, plot_type="bar", max_display=22, show=False)
plt.savefig('Важность признаков.png', bbox_inches='tight')
plt.close()
# Out:
# Анализируем важность признаков в лучшей модели.

# %% [markdown]
# #### Предсказание

# %%
# Предобработка данных
startups_test = startups_test.fillna(0)
startups_test['funding_total_usd'] = startups_test['funding_total_usd']
startups_test['lifetime'] = startups_test['lifetime'].astype(float)
startups_test['time_first'] = startups_test['time_first'].astype(float)
startups_test['time_last'] = startups_test['time_last'].astype(float)
startups_test['funding_rounds'] = startups_test['funding_rounds'].astype(float)

startups_test['country_code'] = startups_test['country_code'].astype(str)


# Удаление ненужных столбцов
X_test = startups_test.drop(['name', 
                            ], axis=1)
X_test_transformed = best_model.named_steps['preprocessor'].transform(X_test)

# Предсказание 
y_test_pred = best_model.named_steps['models'].predict(X_test_transformed)

# Вывод предсказаний
y_test_pred = (y_test_pred >= 0.5).astype(int)
print(np.unique(y_test_pred), y_test_pred.mean())
# Out:
# [0 1] 0.0928

# %%
print('Смотрим различия стобцов train-test: \n',startups_test.shape[1], startups_train.shape[1])
columns_to_print = [col for col in startups_train.columns if col not in startups_test.columns]

#  Смотрим различия столбцов
print(columns_to_print)
# Out:
# Смотрим различия стобцов train-test:
#  607 608
# ['status']

# %%
# Удаление ненужных столбцов из тестового набора данных
X_test = startups_test.drop(['name'], axis=1)

# Preprocessor 2 test
X_test_transformed = best_model.named_steps['preprocessor'].transform(X_test)

# Получение вероятностей предсказаний
y_test_proba = best_model.named_steps['models'].predict_proba(X_test_transformed)[:, 1]

# Установка порога для перевода вероятностей в классы
threshold = 0.45
y_test_pred = (y_test_proba >= threshold).astype(int)

# Вывод уникальных значений
print(np.unique(y_test_pred), y_test_pred.mean())
# Out:
# [0 1] 0.09333333333333334

# %%
y_test_pred = pd.DataFrame(y_test_pred, columns=['status'])
startups_submit = pd.concat([startups_test,y_test_pred], axis=1)
startups_submit = startups_submit[['name', 'status']]
print(startups_submit['status'].mean())
startups_submit['status'] = startups_submit ['status'].map({1: 'closed', 0: 'operating', })
startups_submit.to_csv('startups_submit_v1.csv', index=False)
# Out:
# 0.09333333333333334

# %%
startups_submit['status'].value_counts()
# Out:
# operating    11900
# closed        1225
# Name: status, dtype: int64

# %% [markdown]
# ## Отчет

# %% [markdown]
# ### Введение

# %% [markdown]
# Задачи по данному проекту были поставлены:
# 1. Разработать модель машинного обучения для предсказания продолжения деятельности стартапа.
# 2. Провести полноценный разведочный анализ.
# 3. Сформировать рекомендации будущим создателям стартапов (какие факторы влияют на успешность стартапа).
#
# Анализ проводится на ретроспективных данных о стартапах, которые функционировали в период с 1980 по 2018 годы.
#
# Данное исследование является актуальным, т.к. стартапы являются одним из основных инкубаторовов для создания новых технологий и подходов. И рост количества стартапов это демонстрирует.

# %%
Image(filename='динамика стартапов.png')

# %% [markdown]
# ### Данные и методы исследования
# Исходные данные:
# Датасет состоит из двух файлов: тренировочный набор (около 53к записей) и тестовый набор (около 13к записей). Тренировочный набор содержит целевой признак status, указывающий на то, закрылся стартап или продолжает действовать. Временной период - '1970-01-01' по '2018-01-01'. Дата формирования выгрузки - '2018-01-01'
#
# kaggle_startups_train_01.csv - информация (53 000) стартапах, которые будут использоваться в качестве обучающих данных. kaggle_startups_test_01.csv - информация (13 000) стартапах, которые будут использоваться в качестве тестовых данных. Ваша задача - предсказать значение 'status' для каждого стартапа из этого датасета. kaggle_startups_sample_submit_01.csv - файл с примером предсказаний в правильном формате. name - идентификатор (название) стартапа в тестовом наборе. status - целевой признак. Для каждого стартапа предскажите категориальное значение соответствующее прогнозу ['operating', 'closed'].
#
# Данные предоставлены  по 135 странам, 1037 регионам, и 4478 городам и более 22 000 различных направлений стартапов.
#
# Предоставленные данные имеют "сырой" формат, требующий обработки и подготовки. Так же наличествуют пропуски которые необходимо будет правильно восстановить или удалить. Решение по каждому типу пропусков принималось на основании влияния на итоговую метрику.
#
# Для исследования использовались модели классификаци XGBoost и RandomForest. На первоначальном этапе использовались SVM, LogisticRegression, и другие, но были отвергнуты и удалены из дальнейшей работы, т.к. точность использования этих моделей существеннно уступала.
#
# Для отбора признаков использовались анализ корреляции и анализ важности признаков.

# %% [markdown]
# ### Описание работы и результаты исследования
# Полученные в ходе исследования данные и их анализ.

# %% [markdown]
# В процессе исследования были проведены следующие шаги:
# 1. Загрузка данных.
#
# 2. Предобработка данных в рамках которой:
#
#     2.1. Исправили пропуски.
#
#     2.2. Типы данных скорректировали.
#
#     2.3. Провели проверку на полные дубликаты. Неявные дубликаты не проверяли, на таком массиве уникальных текстовых и объектных значений не целесообразно.
#
#     2.4. Удалили дубли.
#
#     2.5. Удалил Города. Данные дублируются с другими столбцами.Слишком много уникальных значений.
#
#     2.6. Разобрали Категории.
# 3. Разведочный анализ:
#
#     3.1. Проверили и посмотрели каждый признак, убрали выбросы.
#
#     3.2. Построили матрицы корреляции и прроверили на мультиколлинеарность.
#
#     3.3. Убрали признаки которые будут бесполезны для модели.
#
#     3.4. Создали синтетические признаки.
#
#     3.5. Укрупнили категории в признаках и разобрали признак Категории, преобразовав его в вектор.
# 4. Подготовили и обучили модели используя технологию  pipline библиотеки sklearn.
#
#     4.1. Были обучены модели: XGBoost и CATBoost

# %% [markdown]
# Параметры лучшей модели:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('simpleImputer_ohe',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore'))]),
#                                                   Index(['country_code', 'region'], dtype='object')),
#                                                  ('num', StandardScaler(),
#                                                   Index(['funding_total_usd', 'funding_rounds...
#                                feature_types=None, gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.8,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=21, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=11, n_jobs=None,
#                                num_parallel_tree=None, random_state=68, ...))])
#
# - F1 метрика лучшей модели на тренировочной выборке:: 0.9645890497901881
# - Метрика ROC-AUC на тестовой выборке: 0.9997729671666471
# - Метрика F1 на тестовой выборке: 0.9708333333333333

# %% [markdown]
# Эта модель в дальнейшем была использованна для предсказания.
#
#     4.2. Предсказали 13К стартапов из тестовой выборки.
#     4.3. Проведен анализ важности признаков.

# %% [markdown]
# ### Заключение и выводы
# Интерпретация результатов

# %%
Image(filename='Важность признаков.png')

# %% [markdown]
# **По итогам исследования были получены следующие данные:**
#
#     1. Большое количество стартапов закрывается в первые 2 года жизни.
#     2. Чем больше времени прошло с момента последнего раунда финансирования, тем стабильнее стартап.
#     3. Нахождение стартапа в Северной Америке повышает шансы на выживание стартапа.
#     4. Рост объема привлеченного финансирования негативно влияет на выживаемость стартапа.
#     5. Стартапы из Индии и Китая имеют меньше шансов на выживание.

# %% [markdown]
# ### Рекомендации

# %% [markdown]
# - Данное исследование носило "технический" характер общих паттернов, однако при принятии решений о инвестировании необходимо учитывать и другие факторы, так, например, можно рекомендовать произвести анализ проекта инвестирования в соответствии с Методическими рекомендациями Министерства Финансов Российской федерации, провести фундаментальный анализ, в т.ч. анализ бизнес модели.
#
# - В исследовании не учитывался страновой анализ и геополитические риски, это необходимо так же включить как фактор принятия решения.
#
# - В данных было более 800 уникальных категорий стартапов или более 22К их уникальных сочетаний. Целесообразно провести детальный анализ категорий, свести их в группы, построить иерахию и посмотреть в динамике и структуры стартапы по категориям.
#
# - Неплохо бы было наложить результаты прекращения действий стартапов на экономические циклы, а так же сравнить тип и причину экономических кризисов и количество и категории стартапов. Возможно какие то стартапы лучше переживают кризисы, и как зависит наиболее страдающая категория стартапа в зависимости от типа кризиса. В идеале в портфеле должны быть стартапы с низкой корреляцией.
#
# - Необходимо провести исследования самих команд и стартапов с другими признаками, например денежные потоки, структура доходов и расходов, зависимость от ключевых сотрудников и сделать конценсус модель на основе разносторонних факторов.
